# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a52271-pixel/NLP/blob/main/NLP_LAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
medical_corpus = """Patients with diabetes mellitus often experience elevated blood glucose levels due to insufficient insulin production or impaired insulin action.
Hypertension is a common comorbidity that increases the risk of cardiovascular disease and stroke.
Early diagnosis and continuous monitoring can significantly reduce complications in chronic kidney disease.
Treatment plans may include lifestyle modification, pharmacological therapy, and regular clinical follow-up.
Recent studies suggest that inflammation plays a key role in the progression of autoimmune disorders.
Preventive healthcare interventions improve patient outcomes and reduce hospital admissions."""

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab') # Download the missing 'punkt_tab' resource
from nltk.tokenize import word_tokenize
word_tokenize(medical_corpus)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['Patients',
#  'with',
#  'diabetes',
#  'mellitus',
#  'often',
#  'experience',
#  'elevated',
#  'blood',
#  'glucose',
#  'levels',
#  'due',
#  'to',
#  'insufficient',
#  'insulin',
#  'production',
#  'or',
#  'impaired',
#  'insulin',
#  'action',
#  '.',
#  'Hypertension',
#  'is',
#  'a',
#  'common',
#  'comorbidity',
#  'that',
#  'increases',
#  'the',
#  'risk',
#  'of',
#  'cardiovascular',
#  'disease',
#  'and',
#  'stroke',
#  '.',
#  'Early',
#  'diagnosis',
#  'and',
#  'continuous',
#  'monitoring',
#  'can',
#  'significantly',
#  'reduce',
#  'complications',
#  'in',
#  'chronic',
#  'kidney',
#  'disease',
#  '.',
#  'Treatment',
#  'plans',
#  'may',
#  'include',
#  'lifestyle',
#  'modification',
#  ',',
#  'pharmacological',
# ...

# %% [markdown]
# FILTERING STOP WORDS

# %%
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
words_in_quote = word_tokenize(medical_corpus)
words_in_quote
# Out:
# ['Patients',
#  'with',
#  'diabetes',
#  'mellitus',
#  'often',
#  'experience',
#  'elevated',
#  'blood',
#  'glucose',
#  'levels',
#  'due',
#  'to',
#  'insufficient',
#  'insulin',
#  'production',
#  'or',
#  'impaired',
#  'insulin',
#  'action',
#  '.',
#  'Hypertension',
#  'is',
#  'a',
#  'common',
#  'comorbidity',
#  'that',
#  'increases',
#  'the',
#  'risk',
#  'of',
#  'cardiovascular',
#  'disease',
#  'and',
#  'stroke',
#  '.',
#  'Early',
#  'diagnosis',
#  'and',
#  'continuous',
#  'monitoring',
#  'can',
#  'significantly',
#  'reduce',
#  'complications',
#  'in',
#  'chronic',
#  'kidney',
#  'disease',
#  '.',
#  'Treatment',
#  'plans',
#  'may',
#  'include',
#  'lifestyle',
#  'modification',
#  ',',
#  'pharmacological',
#  'therapy',
#  ',',
#  'and',
#  'regular',
#  'clinical',
#  'follow-up',
#  '.',
#  'Recent',
#  'studies',
#  'suggest',
#  'that',
#  'inflammation',
#  'plays',
#  'a',
#  'key',
#  'role',
#  'in',
#  'the',
# ...

# %%
stop_words = set(stopwords.words("english"))
filtered_list =[]
for word in words_in_quote:
    if word.casefold() not in stop_words:
        filtered_list.append(word)
filtered_list
# Out:
# ['Patients',
#  'diabetes',
#  'mellitus',
#  'often',
#  'experience',
#  'elevated',
#  'blood',
#  'glucose',
#  'levels',
#  'due',
#  'insufficient',
#  'insulin',
#  'production',
#  'impaired',
#  'insulin',
#  'action',
#  '.',
#  'Hypertension',
#  'common',
#  'comorbidity',
#  'increases',
#  'risk',
#  'cardiovascular',
#  'disease',
#  'stroke',
#  '.',
#  'Early',
#  'diagnosis',
#  'continuous',
#  'monitoring',
#  'significantly',
#  'reduce',
#  'complications',
#  'chronic',
#  'kidney',
#  'disease',
#  '.',
#  'Treatment',
#  'plans',
#  'may',
#  'include',
#  'lifestyle',
#  'modification',
#  ',',
#  'pharmacological',
#  'therapy',
#  ',',
#  'regular',
#  'clinical',
#  'follow-up',
#  '.',
#  'Recent',
#  'studies',
#  'suggest',
#  'inflammation',
#  'plays',
#  'key',
#  'role',
#  'progression',
#  'autoimmune',
#  'disorders',
#  '.',
#  'Preventive',
#  'healthcare',
#  'interventions',
#  'improve',
#  'patient',
#  'outcomes',
#  'reduce',
# ...

# %% [markdown]
# STEMMING

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
stemmer = PorterStemmer()
words = word_tokenize(medical_corpus)
stemmed_words = [stemmer.stem(word) for word in words]
stemmed_words
# Out:
# ['patient',
#  'with',
#  'diabet',
#  'mellitu',
#  'often',
#  'experi',
#  'elev',
#  'blood',
#  'glucos',
#  'level',
#  'due',
#  'to',
#  'insuffici',
#  'insulin',
#  'product',
#  'or',
#  'impair',
#  'insulin',
#  'action',
#  '.',
#  'hypertens',
#  'is',
#  'a',
#  'common',
#  'comorbid',
#  'that',
#  'increas',
#  'the',
#  'risk',
#  'of',
#  'cardiovascular',
#  'diseas',
#  'and',
#  'stroke',
#  '.',
#  'earli',
#  'diagnosi',
#  'and',
#  'continu',
#  'monitor',
#  'can',
#  'significantli',
#  'reduc',
#  'complic',
#  'in',
#  'chronic',
#  'kidney',
#  'diseas',
#  '.',
#  'treatment',
#  'plan',
#  'may',
#  'includ',
#  'lifestyl',
#  'modif',
#  ',',
#  'pharmacolog',
#  'therapi',
#  ',',
#  'and',
#  'regular',
#  'clinic',
#  'follow-up',
#  '.',
#  'recent',
#  'studi',
#  'suggest',
#  'that',
#  'inflamm',
#  'play',
#  'a',
#  'key',
#  'role',
#  'in',
#  'the',
#  'progress',
#  'of',
#  'autoimmun',
#  'disord',
#  '.',
#  'prevent',
# ...

# %% [markdown]
# LEMMATIZATION

# %%
import nltk
nltk.download('omw-1.4')
nltk.download('wordnet') # Download the missing 'wordnet' resource
from nltk.stem import WordNetLemmatizer
lemmatizer =WordNetLemmatizer()
words = word_tokenize(medical_corpus)
for word in words:
    print(word,"---->",lemmatizer.lemmatize(word))
# Out:
# Patients ----> Patients
# with ----> with
# diabetes ----> diabetes
# mellitus ----> mellitus
# often ----> often
# experience ----> experience
# elevated ----> elevated
# blood ----> blood
# glucose ----> glucose
# levels ----> level
# due ----> due
# to ----> to
# insufficient ----> insufficient
# insulin ----> insulin
# production ----> production
# or ----> or
# impaired ----> impaired
# insulin ----> insulin
# action ----> action
# . ----> .
# Hypertension ----> Hypertension
# is ----> is
# a ----> a
# common ----> common
# comorbidity ----> comorbidity
# that ----> that
# increases ----> increase
# the ----> the
# risk ----> risk
# of ----> of
# cardiovascular ----> cardiovascular
# disease ----> disease
# and ----> and
# stroke ----> stroke
# . ----> .
# Early ----> Early
# diagnosis ----> diagnosis
# and ----> and
# continuous ----> continuous
# monitoring ----> monitoring
# can ----> can
# significantly ----> significantly
# reduce ----> reduce
# ...

# %% [markdown]
# COMPARISION

# %%
from nltk.stem import PorterStemmer, SnowballStemmer, LancasterStemmer, RegexpStemmer, WordNetLemmatizer
porter = PorterStemmer()
lancaster = LancasterStemmer()
snowball = SnowballStemmer(language='english')
regexp = RegexpStemmer('ing|s|e|able', min=4)
lemmatizer = WordNetLemmatizer()

word_list = ["friend", "friendship", "friends", "friendships"]
print("{0:20}{1:20}{2:20}{3:30}{4:40}{5:50}".format("Word","Porter Stemmer","Snowball Stemmer","Lancaster Stemmer",'Regexp Stemmer','WordNetLemmatizer'))
for word in word_list:
    print("{0:20}{1:20}{2:20}{3:30}{4:40}{5:50}".format(word,porter.stem(word),snowball.stem(word),lancaster.stem(word),regexp.stem(word),lemmatizer.lemmatize(word)))
# Out:
# Word                Porter Stemmer      Snowball Stemmer    Lancaster Stemmer             Regexp Stemmer                          WordNetLemmatizer
# friend              friend              friend              friend                        frind                                   friend
# friendship          friendship          friendship          friend                        frindhip                                friendship
# friends             friend              friend              friend                        frind                                   friend
# friendships         friendship          friendship          friend                        frindhip                                friendship
